# %%
# !pip install virtualenv
# !virtualenv .venv
# !apt install libcudnn8 libcudnn8-dev -y
# !apt install ffmpeg
# !source .venv/bin/activate && pip install -r requirements.txt
# As per https://github.com/bmaltais/kohya_ss/issues/2521
# !source .venv/bin/activate && pip install matplotlib-inline

# %%
# !source .venv/bin/activate && python -m speech-unveiler videos --model large-v2 --device cuda --compute-type float16 --builtin-llm
